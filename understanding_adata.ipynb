# %% [markdown]
# ## Understanding Data

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('data/Amazon Sale Report.csv')
# Out:
# /tmp/ipykernel_30036/2490074937.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/Amazon Sale Report.csv')

# %% [markdown]
# ## Univariate analysis

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
df.sample(5)
# Out:
#          index             Order ID      Date                        Status  \
# 22318    22318  405-6942221-9554723  04-17-22                       Shipped
# 45158    45158  407-2314962-3986727  04-03-22                       Shipped
# 114480  114480  402-0652040-9844364  06-10-22                       Shipped
# 37613    37613  402-0431952-1883507  04-08-22                       Shipped
# 14473    14473  403-4681907-0895568  04-21-22  Shipped - Delivered to Buyer
#
#        Fulfilment Sales Channel  ship-service-level    Style  \
# 22318      Amazon      Amazon.in          Expedited  JNE3366
# 45158      Amazon      Amazon.in          Expedited  JNE3440
# 114480     Amazon      Amazon.in          Expedited   SET376
# 37613      Amazon      Amazon.in          Expedited   SET171
# 14473    Merchant      Amazon.in           Standard    BL009
#
#                          SKU Category  ... currency Amount  \
# 22318   JNE3366-KR-1053-XXXL    kurta  ...      INR  376.0
# 45158       JNE3440-KR-N-XXL    kurta  ...      INR  379.0
# 114480        SET376-KR-NP-L      Set  ...      INR  560.0
# 37613       SET171-KR-NP-XXL      Set  ...      INR  792.0
# 14473        BL009-61BLACK-B   Blouse  ...      INR  339.0
#
#                     ship-city   ship-state ship-postal-code  ship-country  \
# 22318   BANGALORE CITY 560002    KARNATAKA         560002.0            IN
# 45158               HYDERABAD    TELANGANA         500016.0            IN
# 114480                 BARGUR   TAMIL NADU         635104.0            IN
# 37613                PALAKKAD       KERALA         678611.0            IN
# 14473                  LAVASA  MAHARASHTRA         412112.0            IN
#
#                                             promotion-ids    B2B  \
# 22318        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 45158        IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 114480       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 37613                                                 NaN  False
# 14473   Amazon PLCC Free-Financing Universal Merchant ...  False
#
#         fulfilled-by Unnamed: 22
# 22318            NaN         NaN
# 45158            NaN         NaN
# 114480           NaN       False
# 37613            NaN         NaN
# 14473      Easy Ship         NaN
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
# df['Status'].value_counts().plot(kind='bar')
sns.histplot(df['Status'])
df['Status'].value_counts()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
df['Sales Channel '].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sales Channel '>

# %%
df['Fulfilment'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# df['Amount'].plot(kind='hist')
sns.histplot(df['Amount'],bins=10)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
df['Qty'].mean()
# Out:
# 0.9044310912967629

# %%
df['Amount'].skew()
# Out:
# 0.8854806405409467

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %% [markdown]
# ## Bivariate analysis and multivariate analysis

# %%
tip=sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tip,x='total_bill',y='tip',hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=titanic,x='pclass',y='age',hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>
