# %% [markdown]
# ## Pandas learning

# %%
import pandas as pd

# %%
df=pd.read_csv('data\Fortune 500 Companies.csv')

# %%
df.head()
# Out:
#                          name  rank  year                industry sector  \
# 0  General Motors Corporation     1  1996  Motor Vehicles & Parts    NaN
# 1          Ford Motor Company     2  1996  Motor Vehicles & Parts    NaN
# 2           Exxon Corporation     3  1996      Petroleum Refining    NaN
# 3       Wal-Mart Stores, Inc.     4  1996   General Merchandisers    NaN
# 4                  AT&T Corp.     5  1996      Telecommunications    NaN
#
#   headquarters_state headquarters_city  market_value_mil  revenue_mil  \
# 0                 MI               NaN               NaN     168828.6
# 1                 MI               NaN               NaN     137137.0
# 2                 TX               NaN               NaN     110009.0
# 3                 AR               NaN               NaN      93627.0
# 4                 NY               NaN               NaN      79609.0
#
#    profit_mil  asset_mil  employees founder_is_ceo female_ceo  \
# ...

# %%
a=df.groupby(['sector'])
len(a)
# Out:
# 21

# %%
a.head()
# Out:
#                     name  rank  year  \
# 9440             Walmart     1  2015
# 9441         Exxon Mobil     2  2015
# 9442             Chevron     3  2015
# 9443  Berkshire Hathaway     4  2015
# 9444               Apple     5  2015
# ...                  ...   ...   ...
# 9782               AECOM   343  2015
# 9790                 PVH   351  2015
# 9793         D.R. Horton   354  2015
# 9813        Ralph Lauren   374  2015
# 9929         Hanesbrands   490  2015
#
#                                       industry                      sector  \
# 9440                     General Merchandisers                   Retailing
# 9441                        Petroleum Refining                      Energy
# 9442                        Petroleum Refining                      Energy
# 9443  Insurance: Property and Casualty (Stock)                  Financials
# 9444               Computers, Office Equipment                  Technology
# ...

# %%
a.groups
# Out:
# {'Aerospace & Defense': [9466, 9484, 9503, 9539, 9563, 9568, 9658, 9691, 9741, 9829, 9835, 9963, 9984, 9999, 10027, 10057, 10059, 10148, 10184, 10221, 10317, 10328, 10429, 10463, 10489, 10495, 10529, 10553, 10555, 10639, 10667, 10712, 10819, 10832, 10931, 10966, 10990, 10998, 11038, 11057, 11058, 11147, 11164, 11215, 11320, 11344, 11346, 11354, 11467, 11485, 11499, 11531, 11547, 11553, 11666, 11668, 11729, 11789, 11810, 11859, 11913, 11978, 11979, 11996, 12022, 12035, 12047, 12165, 12175, 12189, 12296, 12345, 12488, 12493, 12496, 12523, 12525, 12602, 12704, 12766, 12994, 12997, 12999, 13033, 13040, 13145, 13241, 13309, 13496, 13497, 13499, 13544, 13552, 13685, 13757, 13814], 'Apparel': [9545, 9687, 9790, 9813, 9929, 10030, 10170, 10279, 10293, 10387, 10527, 10669, 10774, 10810, 10871, 11028, 11181, 11271, 11360, 11372, 11529, 11691, 11763, 11883, 11912, 11923, 11939, 12024, 12172, 12262, 12375, 12408, 12424, 12434, 12524, 12702, 12843, 12871, 12889, 13022, 13319, 13324, 13397, 13532,
# ...

# %%
df.iloc[9466]
# Out:
# name                                    Boeing
# rank                                        27
# year                                      2015
# industry                   Aerospace & Defense
# sector                     Aerospace & Defense
# headquarters_state                          IL
# headquarters_city                      Chicago
# market_value_mil                      105032.0
# revenue_mil                            90762.0
# profit_mil                              5446.0
# asset_mil                              99198.0
# employees                             165500.0
# founder_is_ceo                              no
# female_ceo                                  no
# newcomer_to_fortune_500                     no
# global_500                                 NaN
# Name: 9466, dtype: object

# %%
a.get_group('Energy').shape[0]
# Out:
# C:\Users\BILAL.COM\AppData\Local\Temp\ipykernel_11456\200317036.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   a.get_group('Energy').shape[0]
# 547

# %%
a.get_group('Financials').shape[0]
# Out:
# C:\Users\BILAL.COM\AppData\Local\Temp\ipykernel_11456\3925339398.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   a.get_group('Financials').shape[0]
# 777

# %%
a.get_group('Technology').shape[0]
# Out:
# C:\Users\BILAL.COM\AppData\Local\Temp\ipykernel_11456\1028107296.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   a.get_group('Technology').shape[0]
# 393

# %%
a.first()
# Out:
#                                                  name  rank  year  \
# sector
# Aerospace & Defense                            Boeing    27  2015
# Apparel                                          Nike   106  2015
# Business Services                       ManpowerGroup   144  2015
# Chemicals                                Dow Chemical    48  2015
# Energy                                    Exxon Mobil     2  2015
# Engineering & Construction                      Fluor   136  2015
# Financials                         Berkshire Hathaway     4  2015
# Food & Drug Stores                         CVS Health    10  2015
# Food, Beverages & Tobacco      Archer Daniels Midland    34  2015
# Health Care                        UnitedHealth Group    14  2015
# Hotels, Restaurants & Leisure              McDonald's   110  2015
# Household Products                   Procter & Gamble    32  2015
# Industrials                               Caterpillar    54  2015
# ...

# %%
a.size()
# Out:
# sector
# Aerospace & Defense               96
# Apparel                           47
# Business Services                169
# Chemicals                        125
# Energy                           547
# Engineering & Construction       112
# Financials                       777
# Food & Drug Stores                55
# Food, Beverages & Tobacco        223
# Health Care                      368
# Hotels, Restaurants & Leisure     89
# Household Products               103
# Industrials                      155
# Materials                        177
# Media                             93
# Motor Vehicles & Parts           100
# Retailing                        422
# Technology                       393
# Telecommunications                81
# Transportation                   158
# Wholesalers                      210
# dtype: int64

# %%
q=df['name'].unique()
q.shape
# Out:
# (2255,)

# %%
df['name'].value_counts()
# Out:
# name
# U.S. Bancorp               28
# Edison International       28
# Johnson & Johnson          28
# Abbott Laboratories        28
# Owens Corning              26
#                            ..
# Par Pacific Holdings        1
# RPM International           1
# Select Medical Holdings     1
# MDU Resources Group         1
# Electronic Arts             1
# Name: count, Length: 2255, dtype: int64

# %%
df.isnull().sum()
# Out:
# name                          0
# rank                          0
# year                          0
# industry                      0
# sector                     9440
# headquarters_state            0
# headquarters_city          6445
# market_value_mil           8755
# revenue_mil                   0
# profit_mil                 8443
# asset_mil                  8440
# employees                  9440
# founder_is_ceo             9440
# female_ceo                 9440
# newcomer_to_fortune_500    9440
# global_500                 9940
# dtype: int64

# %%
df.shape
# Out:
# (13940, 16)

# %%
len(df)
# Out:
# 13940
